# %% [markdown]
# # Colin's Untappd Data - Type Analysis

# %% [markdown]
# ## Introduction to data
#
# The very first step of every data analysis is to take a precursory look at what the data is. Simply put, this section tells us how many data points this user has and what features are included. For the Untappd user data, we have info about the beer (name, style, type, ABV, IBU), user feedback (comments, rating), location information for both the brewery and venue and time data.
#
# This dataset is all the Untappd data from one user, Colin Dixon. Check-ins span July, 2013 to present day. There are 2,166 unique check-ins. Each check-in has potentially 26 distinct attributes. Probably one of the most notable attribute is the user's rating of the check-in. Of the original 2,166 total check-ins, 2,152 have a user rating. The user's rating average is 4.10 with a standard deviation of 0.47.
#
# Initial observation of the user rating's histogram revealed an odd bimodal peak. Upon further investigation I discovered that in April, 2015, the Untappd rating system changed from 0.5 increments to 0.25 increments. The change lends to an inconsistency in the data. Consequently, I filtered the data to only include check-ins after April, 2015. The resulting dataset's user ratings consist of 1490 data points normally distributed with mean 4.18 and standard deviation 0.38.
#
# Unless otherwise specified, all further analysis is performed on the filtered data to increase reliability of the data set.

# %%
#Ignore deprecated warning buried in 3rd party packages
#(comment initially to look at warning and suppress warnings later)
import warnings
warnings.filterwarnings('ignore')

#Import all libraries needed
import pandas as pd #dataframe organization
import matplotlib.pyplot as plt #plotting
import matplotlib.gridspec as gridspec #plotting
from datetime import datetime, timedelta, date
import numpy as np
import util
import seaborn as sns
from scipy.stats import f as f
from scipy import stats

# %%
#Load the data and take a peek

#Import data into a pandas df

untappd_all = pd.read_csv("../data/user1.csv", encoding = "ISO-8859-1")

print('Looking at the first few rows: ')
untappd_all.head()
# Out:
# Looking at the first few rows:
#                 beer_name                       brewery_name  \
# 0      Chocolate Sombrero                        Clown Shoes
# 1            Funky Galaxy               Prairie Artisan Ales
# 2  Mesquite Smoked Porter  Ranger Creek Brewing & Distilling
# 3              Hefeweizen            Widmer Brothers Brewing
# 4                    Matt    Hair of the Dog Brewing Company
#
#                             beer_type  beer_abv  beer_ibu  \
# 0  Stout - American Imperial / Double       9.0         6
# 1              Saison / Farmhouse Ale       8.0         0
# 2                         Smoked Beer       6.4        20
# 3                          Hefeweizen       4.9        30
# 4               Strong Ale - American      11.5         0
#
#                                              comment venue_name venue_city  \
# 0                                                NaN        NaN        NaN
# 1  Very hoppy for a farmhouse ale. Still drinkabl...        NaN        NaN
# 2       Delicious, very richly smoked strong porter.        NaN        NaN
# 3           Drinkable, but nothing remotely special.        NaN        NaN
# 4  Simple put, this is as good as it gets when it...        NaN        NaN
#
#   venue_state venue_country    ...                            brewery_url  \
# 0         NaN           NaN    ...       https://untappd.com/brewery/7583
# 1         NaN           NaN    ...      https://untappd.com/brewery/37713
# 2         NaN           NaN    ...       https://untappd.com/brewery/2922
# 3         NaN           NaN    ...       https://untappd.com/brewery/3028
# 4         NaN           NaN    ...        https://untappd.com/brewery/622
#
#    brewery_country  brewery_city brewery_state flavor_profiles purchase_venue  \
# 0    United States       Ipswich            MA             NaN            NaN
# 1    United States         Krebs            OK             NaN            NaN
# 2    United States   San Antonio            TX             NaN            NaN
# 3    United States      Portland            OR             NaN            NaN
# 4    United States      Portland            OR             NaN            NaN
#
#   serving_type checkin_id     bid brewery_id
# 0          NaN   38028941  126867       7583
# 1          NaN   38029429  325858      37713
# 2          NaN   38053052   13677       2922
# 3          NaN   38262335    6395       3028
# 4          NaN   38368018   12670        622
#
# [5 rows x 26 columns]

# %%
#Note some important points about the data (number of points, available features, etc)

print('Looking at some high level of the data')
print('Total number of entries: ', untappd_all.shape[0])
print('Total number of raw attributes: ',  untappd_all.shape[1])

print('')
print('More Info: ')
print('')
print(untappd_all.info())
# Out:
# Looking at some high level of the data
# Total number of entries:  2166
# Total number of raw attributes:  26
#
# More Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2166 entries, 0 to 2165
# Data columns (total 26 columns):
# beer_name          2166 non-null object
# brewery_name       2166 non-null object
# beer_type          2166 non-null object
# beer_abv           2166 non-null float64
# beer_ibu           2166 non-null int64
# comment            1463 non-null object
# venue_name         1450 non-null object
# venue_city         1191 non-null object
# venue_state        1443 non-null object
# venue_country      1450 non-null object
# venue_lat          1450 non-null float64
# venue_lng          1450 non-null float64
# rating_score       2152 non-null float64
# created_at         2166 non-null object
# checkin_url        2166 non-null object
# beer_url           2166 non-null object
# brewery_url        2166 non-null object
# brewery_country    2166 non-null object
# brewery_city       2153 non-null object
# brewery_state      2116 non-null object
# flavor_profiles    210 non-null object
# purchase_venue     224 non-null object
# serving_type       474 non-null object
# checkin_id         2166 non-null int64
# bid                2166 non-null int64
# brewery_id         2166 non-null int64
# dtypes: float64(4), int64(4), object(18)
# memory usage: 440.0+ KB
# None
# 2013-07-20 21:35:01

# %%
#Data cleaning - removing the duplicate check-ins
#Assuming the file stays in chronological order, calculate each pair of times checked in and if close, check names
rows_to_delete = []
for index, row in untappd_all.iterrows():
    if index >0:
        datetime_curr = datetime.fromisoformat(row['created_at'])
        datetime_prev = datetime.fromisoformat(untappd_all.iloc[index-1]['created_at'])
        #Check if the time difference is less than an hour
        diff_timedelta = datetime_curr - datetime_prev
        if diff_timedelta < timedelta(hours=1):
            #Now check that one of the names doesn't completely include another of the names
            #(e.g., "Gingerbread Stout" and "Gingerbread Stout (2017)")
            if row['beer_name'] in untappd_all.iloc[index-1]['beer_name'] and row['bid'] != untappd_all.iloc[index-1]['bid']:
                rows_to_delete.append(index)
            if untappd_all.iloc[index-1]['beer_name'] in row['beer_name'] and untappd_all.iloc[index-1]['bid'] != row['bid']:
                rows_to_delete.append(index-1)
#Drop the rows
untappd_all.drop(index=rows_to_delete, inplace=True)

# %%
#Create a new dataframe containing just unique beer info (for later)
labels, uniques = pd.factorize(untappd_all['bid'])
bid_columns = ['beer_name', 'beer_type', 'beer_abv', 'beer_ibu', 'beer_url', 'brewery_id', 'bid']
bid_df = pd.DataFrame(untappd_all.loc[untappd_all['bid'] == uniques[i], bid_columns].iloc[0] for i in range(uniques.size))

# %%
#Look at global ratings data

scoring_increment = 0.25

plt.figure(1, figsize=(15, 7))
plt.subplot(121)
plt.hist(untappd_all['rating_score'], bins=np.arange(untappd_all['rating_score'].min(), untappd_all['rating_score'].max()+scoring_increment, 0.25), align='right')
plt.xlabel('Beer Rating')
plt.ylabel('Number of Ratings')

#Filter for after 0.25 increments were introduced
untappd_all['created_at'] = untappd_all['created_at'].astype('datetime64[ns]')
date_changed = datetime.fromisoformat("2015-04-27 19:00:00")
untappd_ratingssyschanged = untappd_all.loc[untappd_all['created_at'] > date_changed]

plt.subplot(122)
plt.hist(untappd_ratingssyschanged['rating_score'], bins=np.arange(untappd_ratingssyschanged['rating_score'].min(), untappd_ratingssyschanged['rating_score'].max()+scoring_increment, 0.25), align='right')
plt.xlabel('Beer Rating')
plt.ylabel('Number of Ratings')


plt.show()

# %%
untappd_all['rating_score'].describe()
# Out:
# count    2087.000000
# mean        4.085649
# std         0.474987
# min         1.500000
# 25%         3.750000
# 50%         4.000000
# 75%         4.500000
# max         5.000000
# Name: rating_score, dtype: float64

# %%
untappd_ratingssyschanged['rating_score'].describe()
# Out:
# count    1490.000000
# mean        4.179698
# std         0.379723
# min         2.000000
# 25%         4.000000
# 50%         4.250000
# 75%         4.500000
# max         5.000000
# Name: rating_score, dtype: float64

# %% [markdown]
# ## What's in a name?
#
# This analysis takes a simple look at how many different types of beers are in the dataset (and does the data indicate any favorites).
#
# How many unique beers are we looking at?
#
# OK, it appears my hubby drank a LOT of different beers in since he began logging them in July, 2013. In fact, there are precisely 2,166 unique entries. But how many different beers did he drink? I took a look at the frequency for each unique beer. Fortunately, the Untappd data includes a integer beer ID (bid) to ease matching.
#
# I found that, not surprisingly, hubs is a beer adventure seeker. He has 1,464 unique check-ins, of which 1,118 beers he only checked into once!

# %%
#Categorize the beer id
labels, uniques = pd.factorize(untappd_all['bid'])

#Bin the number of times a beer is drank
labels_count, labels_index = np.histogram(labels, bins = range(uniques.size+1))

#Bin the frequency of times a beer is drank
freq_labels, freq_labels_index = np.histogram(labels_count, bins = range(labels_index.size+1))


#Create a dataframe with only hist bins that were populated
df_label_freq = pd.DataFrame(data={'Number of Unique Check-Ins': freq_labels, 'Frequency of Unique Check-Ins Consumed': freq_labels_index[:-1]})
df_label_freq.drop(df_label_freq.loc[df_label_freq['Number of Unique Check-Ins'] == 0].index, inplace=True)
df_label_freq.set_index('Frequency of Unique Check-Ins Consumed', inplace=True)

#Show the beer frequency information
df_label_freq.style.bar(color='yellow')
# Out:
# <style  type="text/css" >
#     #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 100.0%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 16.3%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 6.3%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 3.0%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 1.6%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.8%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.7%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row7_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.1%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row9_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row10_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.1%, transparent 0%);
#         }    #T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row12_col0 {
#             width:  10em;
#              height:  80%;
#         }</style>
# <table id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Number of Unique Check-Ins</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Frequency of Unique Check-Ins Consumed</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row0_col0" class="data row0 col0" >1095</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row1_col0" class="data row1 col0" >179</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row2_col0" class="data row2 col0" >70</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row3" class="row_heading level0 row3" >4</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row3_col0" class="data row3 col0" >34</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row4" class="row_heading level0 row4" >5</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row4_col0" class="data row4 col0" >19</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row5" class="row_heading level0 row5" >6</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row5_col0" class="data row5 col0" >10</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row6" class="row_heading level0 row6" >7</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row6_col0" class="data row6 col0" >9</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row7" class="row_heading level0 row7" >8</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row7_col0" class="data row7 col0" >1</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row8" class="row_heading level0 row8" >9</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row8_col0" class="data row8 col0" >2</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row9" class="row_heading level0 row9" >10</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row9_col0" class="data row9 col0" >1</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row10" class="row_heading level0 row10" >11</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row10_col0" class="data row10 col0" >1</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row11" class="row_heading level0 row11" >12</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row11_col0" class="data row11 col0" >2</td>
#     </tr>    <tr>
#         <th id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493level0_row12" class="row_heading level0 row12" >13</th>
#         <td id="T_a1735fb0_f4a6_11e8_ad9c_542696d8d493row12_col0" class="data row12 col0" >1</td>
#     </tr></tbody>
# </table>

# %%
#What about vintage, version, ghost, batch, blend, volume... does it ever end?

# %%
#Identify most frequently drank beers
#Remove the double check-ins (vintage and regular)

labels, uniques = pd.factorize(untappd_all['bid'])
df_unique_bids = pd.DataFrame(data={'Number of Check-Ins': labels_count, 'bid': uniques})

df_favorite_unique_bids = df_unique_bids.loc[df_unique_bids['Number of Check-Ins'] > 5]

df_favorite_unique_bids_merged = df_favorite_unique_bids.merge(bid_df, left_on='bid', right_on='bid')


#Show the beer frequency information
df_favorite_unique_bids_merged.sort_values(by = ['Number of Check-Ins'], inplace=True)
df_favorite_unique_bids_merged.style.bar(color='orange')
# Out:
# <style  type="text/css" >
#     #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 64.1%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 42.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 60.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row0_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 1.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row1_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 19.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 16.7%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 13.3%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row1_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row2_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 45.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 18.1%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 60.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row2_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 1.2%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row3_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 89.1%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 36.2%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 53.3%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row3_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 34.6%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row4_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 1.1%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 34.8%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.7%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row4_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 0.8%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 1.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 34.8%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 80.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row5_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 2.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row6_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 0.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 31.2%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 14.7%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row6_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 0.6%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row7_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 0.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row7_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 33.3%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row7_col7 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 1.0%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row8_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 69.4%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row8_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 36.2%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row8_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 53.3%, transparent 0%);
#         }    #T_a18baaa2_f4a6_11e8_ad9c_542696d8d493row8_col7 {
#             width:  10em;
#              height:  8

# %%
#Comparison of variants
